# %%
import pandas as pd
file = "TrainA_with_SC38012.xlsx"
    # 1. Load data
    
df = pd.read_excel(file)

df.head()
# Out:
#   Description  CONDY TO SIDE REBLR   \
# 0       Units                 deg C
# 1         NaN                   NaN
# 2        Date       SDT-TI38A305.AI
# 3  2025-01-01            153.608032
# 4  2025-01-01            153.608032
#
#   STABILISER COLUMN                                                 \
# 0                                               mbar
# 1                                                NaN
# 2                                   SDT-PDI38A302.AI
# 3                                                  0
# 4                                                  0
#
#   REBLR HOT OIL ISOL                                                \
# 0                                               m3/h
# 1                                                NaN
# 2                                    SDT-FI38A401.AI
# 3                                         177.140656
# 4                                         177.140656
#
#    STABR GAS TO RECOMP   STABR GAS TO RECOMP .1  \
# ...
